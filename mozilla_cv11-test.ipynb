# %%
# !export CUDA_VISIBLE_DEVICES=0

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
# os.environ['CUDA_VISIBLE_DEVICES']='0,1'
os.environ['CUDA_LAUNCH_BLOCKING']='1'
import torch
# torch.cuda.set_device(0)
print(torch.cuda.current_device())
# Out:
# 0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
# cudaSetDevice(0)
#dataset transcript要在dataset資好夾調
#cuda 在basesolver init調
#dataset要在data.py設定

# %%
#! python
# -*- coding: utf-8 -*-
# Author: kun
# @Time: 2019-10-29 20:29

import yaml
import torch
import argparse
import numpy as np

class Para(object):
    a=1

def force_cudnn_initialization():
    s = 32
    dev = torch.device('cuda:0')
    torch.nn.functional.conv2d(torch.zeros(s, s, s, s, device=dev), torch.zeros(s, s, s, s, device=dev))
    
#force_cudnn_initialization()
def main():
    # For reproducibility, comment these may speed up training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Arguments
#     parser = argparse.ArgumentParser(description='Training E2E asr.')
#     parser.add_argument('--config', type=str, help='Path to experiment config.')
#     parser.add_argument('--name', default=None, type=str, help='Name for logging.')
#     parser.add_argument('--logdir', default='log/', type=str,
#                         help='Logging path.', required=False)
#     parser.add_argument('--ckpdir', default='ckpt/', type=str,
#                         help='Checkpoint path.', required=False)
#     parser.add_argument('--outdir', default='result/', type=str,
#                         help='Decode output path.', required=False)
#     parser.add_argument('--load', default=None, type=str,
#                         help='Load pre-trained model (for training only)', required=False)
#     parser.add_argument('--seed', default=0, type=int,
#                         help='Random seed for reproducable results.', required=False)
#     parser.add_argument('--cudnn-ctc', action='store_true',
#                         help='Switches CTC backend from torch to cudnn')
#     parser.add_argument('--njobs', default=32, type=int,
#                         help='Number of threads for dataloader/decoding.', required=False)
#     parser.add_argument('--cpu', action='store_true', help='Disable GPU training.')
#     parser.add_argument('--no-pin', action='store_true',
#                         help='Disable pin-memory for dataloader')
#     parser.add_argument('--test', action='store_true', help='Test the model.')
#     parser.add_argument('--no-msg', action='store_true', help='Hide all messages.')
#     parser.add_argument('--lm', action='store_true',
#                         help='Option for training RNNLM.')
#     # Following features in development.
#     parser.add_argument('--amp', action='store_true', help='Option to enable AMP.')
#     parser.add_argument('--reserve-gpu', default=0, type=float,
#                         help='Option to reserve GPU ram for training.')
#     parser.add_argument('--jit', action='store_true',
#                         help='Option for enabling jit in pytorch. (feature in development)')
#     ###
#     paras = parser.parse_args()
    paras = Para()
#     paras.config = './config/aishell_asr_example_lstm4atthead1-test.yaml'
#     paras.name = None
#     paras.logdir = 'log/'
#     paras.ckpdir = 'ckpt/'
#     paras.outdir = 'result/'
#     paras.load = None
#     paras.seed = 0
#     paras.cudnn_ctc = False
#     paras.cpu = False
#     paras.no_pin = False
#     paras.test = True
#     paras.no_msg = False
#     paras.lm = False
#     paras.amp = False
#     paras.reserve_gpu = 0
#     paras.jit = False
    setattr(paras, 'config', './config/mozillacv11_asr_stm4atthead-test.yaml')
    setattr(paras, 'name', None)
    setattr(paras, 'logdir', 'log/')
    setattr(paras, 'ckpdir', 'ckpt/')
    setattr(paras, 'outdir', 'result/')
    setattr(paras, 'load', None)
    setattr(paras, 'seed', 0)
    setattr(paras, 'cudnn_ctc', False)
    setattr(paras, 'njobs',1)
    setattr(paras, 'cpu', False)
    setattr(paras, 'no_pin', False)
    setattr(paras, 'test', True)
    setattr(paras, 'no_msg', False)
    setattr(paras, 'lm', False)
    setattr(paras, 'amp', False)
    setattr(paras, 'reserve_gpu', 0)
    setattr(paras, 'jit', False)
    setattr(paras, 'gpu', not paras.cpu)
    setattr(paras, 'pin_memory', not paras.no_pin)
    setattr(paras, 'verbose', not paras.no_msg)
    force_cudnn_initialization()

    config = yaml.load(open(paras.config, 'r'), Loader=yaml.FullLoader)

    np.random.seed(paras.seed)
    torch.manual_seed(paras.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(paras.seed)

    # Hack to preserve GPU ram just incase OOM later on server
    if paras.gpu and paras.reserve_gpu > 0:
        buff = torch.randn(int(paras.reserve_gpu * 1e9 // 4)).cuda()
        del buff

    if paras.lm:
        # Train RNNLM
        from train_lm import Solver

        mode = 'train'
    else:
        if paras.test:
            # Test ASR
            assert paras.load is None, 'Load option is mutually exclusive to --test'
            from test_asr import Solver

            mode = 'test'
        else:
            # Train ASR
            from train_asr import Solver

            mode = 'train'

    print("\nUsing {} mode\n".format(mode))
    solver = Solver(config, paras, mode)
    solver.load_data()
    solver.set_model()
    solver.exec()

# %%
main()
# Out:
# Using test mode
#
# [INFO] Evaluating result of tr. config @ ../LAS_Mandarin_PyTorch-master/config/mozillacv11_asr_stm4atthead.yaml
# Prepare dataloader for training/validation
# Load text encoder : CharacterTextEncoder
# Interface for creating all kinds of dataset
# import Mozillacv11Dataset as Dataset
# [Mozillacv11Dataset] path: /mnt/usb/jason3/cv-corpus-11.0-2022-09-21/zh-TW/wavs, split: ['devshort']
# Mozillacv11Dataset devshort found wav data: 10
# text len: 10
# remove None, then wav data: 10, text len: 10
# ['途中開始下雪了', '我也有帶來', '找不到真實世界中的依靠', '學校為特別班加課', '下次給我注意一點', '津貼補助的政策奏效', '就開始等放假啦', '這是我想要說的嗎', '他痛哭起來', '回到一二號巴士站']
# [[2839, 1], [1073, 1], [1099, 1], [736, 1], [49, 1], [1603, 1], [796, 1], [2842, 1], [105, 1], [551, 1]]
# [Mozillacv11Dataset] path: /mnt/usb/jason3/cv-corpus-11.0-2022-09-21/zh-TW/wavs, split: ['test']
# Mozillacv11Dataset test found wav data: 14709
# text len: 14709
# remove None, then wav data: 14709, text len: 14709
# ['我可以慢慢聽妳說', '每天帶小女兒走路上學', '眼神如此無助', '拉麵共和國', '伺服器出現異常', '但是到時候你努力到死', '司機不知道我在哪', '蹣跚在沙漠之中', '兩國總統都沒有直接通過電話', '等到三十四分都還沒到', '昨天爬四聖山', '喊著什麼不要殺我', '家裡沒別人了', '但是有個規則', '我們急急忙忙', '頭也不回', '她還是在台北過的很好', '拍照嘍哈哈', '我們繼續坐車', '臺北市政府警察局中山分局', '零至六個月之', '乘坐汽車而不是轎子', '小女兒國小畢業', '重量也是沒差多少', '我們只有四個人', '我就上網讀資料', '直到下一個三十年', '茶香好香', '竹梅公路', '我寫在這邊', '龍潭交流道', '當作抓周選項', '眼球中央電視台', '呂宋海峽', '新北市特二號道路', '感謝指點', '開靜音', '大順一路', '苗栗縣三義鄉', '新疆的官網連不上', '澎湖縣西嶼鄉', '芬草交流道', '看到坑洞就想填平', '見過商業力量進駐前後的對比', '從零重新思考', '崇拜希特勒', '這則謠言其實已流傳許久', '讓我們做一個跟日本會場連線的動作', '就純粹是商業機制', '若其他地主還有意見', '當董事長了', '中國評論通訊社', '屆時仍有疑問或不滿意', '媒體素養專欄', '沒附連結的影片不會有病毒', '全部做成例句辭典好了', '聽我唱歌啊為什麼你不肯聽我唱歌', '如果機器人實在看不出來', '我們也願意派出人力來幫忙', '以及發覺彼此共同點', '任何情勢', '勤崴國際為了更新電子地圖', '請他們作修正', '我尊重這個歷史事實', '為臺灣的年輕人做的事', '讓受害者以及家屬覺得', '未來我和新政府', '五大創新研發計畫', '利益共享原則', '對於能源的選擇', '東勢大橋', '苗栗縣南橫公路', '某河口附近如圖所示', '桃園捷運機場線', '鐵道橋梁', '東豐自行車道', '燕巢系統交流道', '把政治上的主權拿到人民手裡', '社團中有人發文討論', '戴耳環的比例超過一半', '要來繼續', '內灣線', '在台南', '他們說出席委員都在睡覺', '我也是這麼想的', '好像蠻多地方停電了', '我在蘆洲有一棟房子', '這次好貴', '這邊三顆電池也用光了', '勞保局提醒', '假日哪裡好玩', '就是為了吃豬肉', '運用數位工具及知識平台打造獨特產品', '就開始等放假啦', '兩個人認真的討論起來', '網路行銷及大數據', '我拿了我的備用帽子', '一二三地號範圍內的四五六地號', '任何改革', '剛才已發給各位這方面的資料', '文化資產保存法', '我要的就是', '在時效内未提出', '幕僚組織及職掌', '許多清楚的裁示', '組長是由司法院尤廳長擔任', '是司法界最後的堡壘', '一夜轉變', '百尺竿頭', '好的感謝您', '公聽會舉辦的主旨', '調查結果', '會議的目標非常重要', '早上忘了帶便當出門了', '流浪地球', '水表照片', '不論他做的是什麼工作', '捷運工程局', '記得晾衣服', '這是我們的構想', '高鐵聯外公路嘉義段', '糧食作物以玉米為主', '一隻手大約佔了全身百分之九的重量', '比剛剛順很多了', '收集後用以發電', '台北捷運文山線', '台灣海峽', '大家都怎麼做的呢', '水上漂到日本', '熱情熱血', '有定期月聚會', '為了避免台灣的社會', '請求指揮官支援', '同時著地', '造成中國人像一盤散沙', '是七萬四千五百人', '記錄日期的前數日皆為晴天', '投兩票需要四點', '中午根本熱到無法呼吸', '但也有轉機', '一個穩定的群落', '人口約佔百分之零點四', '中國一點都不能少', '是順乎天命應於民心的事', '泰山不讓土壤故能成其大', '搬遷剩餘的舊桌子要出清', '板橋第二運動場', '七賢自強路口東北側', '鳳山公二八公園', '臺大新生教室南側', '明志書院立體停車場', '中正瑞源路口西南側', '新譯史記', '高雄市立圖書館湖內分館', '板橋第一運動場', '中山八德路口西南側', '遠雄自貿港區加值園區', '中國醫藥大學水湳校區', '也不用到地下吧', '提出申請', '爬資料爬好爬滿', '仍是三十年前', '不當應用於非經授權之範圍', '教材提到愛情', '你需要一點斷捨離', '跳樓事件', '今天參加邪教聚會', '歡迎大家多多救濟', '害怕這病態的社會養育了一個殺人魔', '個案實驗建立通則', '春雨開始下了', '表達的意見未經深思熟慮', '同事運用開源素材', '沒任何回應', '如果又是一群人聚在一起', '蘋果日報', '當一個人主動搭籠子時', '為什麼換了好多簡體字的名片啊', '阿拉伯數字跟英文字', '跟生理女性的腦更為接近', '不然肯定骨折', '降低罹患癌症的機率', '第一次世界大戰結束', '當時正在拖地', '想去的景點大概排了', '雕塑科木雕部', '案例經驗分享', '河畔的搗衣聲', '歡迎大家來找我', '自家經營碾米廠', '我自己處理好了', '可享二十元優惠', '整理完畢後', '我覺得太痛苦了', '還不用緊張', '會有很多有趣的應用', '穿什麼衣服', '所有的事情一起爆出來', '幾乎沒有辦法完成任何事情', '三峽祖師廟', '修理好會再出來', '近三年離職率一直在降', '過比我們還好的生活', '今天來就是來看看', '至少給我們兩週的時間', '死有輕於紅毛丹重於泰山八寶粥', '長江後浪推前浪噗浪死在沙灘上', '激怒李維', '建議及改進的方式', '在天願作比翼鳥大難臨頭各自飛', '檢視是否符合基本的原則', '學海無涯回頭是岸', '一元復始雙喜臨門四海遊龍八方雲集', '山不在高有仙則名水不在深史萊哲林', '並提示完成百分比', '提示簡單的流程進度', '打算成立一個工作小組', '及相關說明修改', '還是要花三十分鐘安裝', '早起的鳥兒有蟲吃晚起的蟲兒被鳥吃', '有沒有足夠的判斷力與專業能力', '集中在聆聽不同意見的多元性', '願我們能協力學習', '解除距離的限制', '我們看見用戶體驗', '是最重要的評價因素', '甚至連年紀很小的參與者', '也同時創造出嶄新的協作模式', '台南端', '阿里山線', '已經身份認證完成', '彰化縣和美鎮', '台中市三豐路', '要對不起雞了', '臺灣海峽', '南通灣交流道', '先簡化一下', '七股交流道', '屏東至高雄的鐵路幹線', '利吉大橋', '芳安路', '山月吊橋', '比較適合發一般討論', '新北市林口區和桃園市龜山區', '台北捷運松新線', '獅潭端', '高雄市四維路', '平溪線', '台南小港機場快線', '伸港交流道', '反正這個頻道隨便亂聊', '南投縣埔里鎮', '中華北路', '中和新蘆線', '昨天都已經上線了', '台北市康定路', '查了兩篇文章', '我說的內容', '員林大排兩側平面道路', '進德大橋', '北部橫貫公路', '為落實全民福利', '結構調整和永續發展', '聽重金屬甩頭', '想蒐集清單', '東南亞受兩大文明古國影響', '我好想吃薄皮嫩雞', '陳委員的提議値得思考', '和睦相處', '太陽餅裡沒有太陽', '今天有個消息', '造成少數語言的使用度越來越低', '台灣各個企業', '你的屁股辣不辣', '並不是指記者和媒體從業人員的素養', '說明增加信託費用的合理性', '這邊做一個簡短的說明', '各會員國應秉持善意', '本次的紅茶也升級為金萱茶', '從一開始手忙腳亂', '拿出手機這個動作', '如果是從小在這種極度的社群', '好開心', '在法國大革命期間', '後來我覺得不便宜', '從此飲食都需要非常注意', '你等一下再回來就好了', '召開一般程序審查會議', '在公開的網購平臺下標', '不在這裡會在哪裡啊', '昏黃的橘色光芒映照著街景', '過去一年經濟的表現', '氣的聲音越來越大', '研究機構包括學校', '風景因山林開墾而消失', '才不再會忘記', '和老家完全不一樣', '聽說隔壁賺了不少
# [INFO] I/O spec.  | Audio feature = fbank	| feature dim = 120	| Token type = character	| Vocab size = 3255
# [INFO] Evaluation target = ../LAS_Mandarin_PyTorch-master/ckpt/mozillacv11_asr_stm4atthead_sd0/best_att.pth (recorded wer = 0.13 %)
# [INFO] Decode spec| Beam size = 2	| Min/Max len ratio = 0.0/10.0
# [INFO] Performing instance-wise beam decoding on dev set. (NOTE: use --njobs to speedup)
#   0%|          | 0/10 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     861             try:
# --> 862                 tasks = self._ready_batches.get(block=False)
#     863             except queue.Empty:
#
# /opt/tljh/user/lib/python3.7/queue.py in get(self, block, timeout)
#     166                 if not self._qsize():
# --> 167                     raise Empty
#     168             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-8-f52dfe8876d0> in main()
#     129     solver.load_data()
#     130     solver.set_model()
# --> 131     solver.exec()
#
# ~/LAS_Mandarin_PyTorch-master/test_asr.py in exec(self)
#     104                 # Parallel beam decode
#     105                 results = Parallel(n_jobs=self.paras.njobs)(
# --> 106                     delayed(beam_decode_func)(data) for data in tqdm(ds))
#     107                 self.verbose(
#     108                     'Results/Beams will be stored at {} / {}.'.format(self.cur_output_path, self.cur_beam_path))
#
# ~/.local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1083             # remaining jobs.
#    1084             self._iterating = False
# -> 1085             if self.dispatch_one_batch(iterator):
#    1086                 self._iterating = self._original_iterator is not None
#    1087
#
# ~/.local/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     871                 big_batch_size = batch_size * n_jobs
#     872
# --> 873                 islice = list(itertools.islice(iterator, big_batch_size))
#     874                 if len(islice) == 0:
#     875                     return False
#
# ~/LAS_Mandarin_PyTorch-master/test_asr.py in <genexpr>(.0)
#     104                 # Parallel beam decode
#     105                 results = Parallel(n_jobs=self.paras.njobs)(
# --> 106                     delayed(beam_decode_func)(data) for data in tqdm(ds))
#     107                 self.verbose(
#     108                     'Results/Beams will be stored at {} / {}.'.format(self.cur_output_path, self.cur_beam_path))
#
# /opt/tljh/user/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1183
#    1184         try:
# -> 1185             for obj in iterable:
#    1186                 yield obj
#    1187                 # Update and possibly print the progressbar.
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1314
#    1315             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1316             idx, data = self._get_data()
#    1317             self._tasks_outstanding -= 1
#    1318             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1270         elif self._pin_memory:
#    1271             while self._pin_memory_thread.is_alive():
# -> 1272                 success, data = self._try_get_data()
#    1273                 if success:
#    1274                     return data
#
# ~/.local/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1118         #   (bool: whether successfully get data, any: data if successful else None)
#    1119         try:
# -> 1120             data = self._data_queue.get(timeout=timeout)
#    1121             return (True, data)
#    1122         except Exception as e:
#
# /opt/tljh/user/lib/python3.7/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /opt/tljh/user/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
print('asd')

# %%
# !python eval.py --file ~/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv
# Out:
# ============  Result of /home/jupyter-jason3/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv ============
#  -----------------------------------------------------------------------
# | Statics		|  Truth	|  Prediction	| Abs. Diff.	|
#  -----------------------------------------------------------------------
# | Avg. # of chars	|  8.01	|  8.10	|  0.16		|
# | Avg. # of words	|  1.00	|  1.00	|  0.00		|
#  -----------------------------------------------------------------------
#  ---------------------------------------------------------------
# | Error Rate (%)| Mean		| Std.		| Min./Max.	|
#  ---------------------------------------------------------------
# | Character	| 7.9479	| 21.68		| 0.00/240.00	|
# | Word		| 18.1725	| 38.56		| 0.00/100.00	|
#  ---------------------------------------------------------------
# Note : If the text unit is phoneme, WER = PER and CER is meaningless.
