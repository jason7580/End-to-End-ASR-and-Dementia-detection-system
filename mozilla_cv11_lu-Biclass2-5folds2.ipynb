# %%
# !export CUDA_VISIBLE_DEVICES=0

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'
# os.environ['CUDA_VISIBLE_DEVICES']='0,1'
os.environ['CUDA_LAUNCH_BLOCKING']='1'
import torch
# torch.cuda.set_device(0)
print(torch.cuda.current_device())
# Out:
# 0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
# cudaSetDevice(0)
#dataset transcript要在dataset資好夾調
#cuda 在basesolver init調
#dataset要在data.py設定

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'
# os.environ['CUDA_VISIBLE_DEVICES']='0,1'
os.environ['CUDA_LAUNCH_BLOCKING']='1'
import torch
# torch.cuda.set_device(0)
print(torch.cuda.current_device())
#! python
# -*- coding: utf-8 -*-
# Author: kun
# @Time: 2019-10-29 20:29

import yaml
import torch
import argparse
import numpy as np

class Para(object):
    a=1

def force_cudnn_initialization():
    s = 32
    dev = torch.device('cuda:0')
    torch.nn.functional.conv2d(torch.zeros(s, s, s, s, device=dev), torch.zeros(s, s, s, s, device=dev))
    
#force_cudnn_initialization()
def main():
    # For reproducibility, comment these may speed up training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Arguments
#     parser = argparse.ArgumentParser(description='Training E2E asr.')
#     parser.add_argument('--config', type=str, help='Path to experiment config.')
#     parser.add_argument('--name', default=None, type=str, help='Name for logging.')
#     parser.add_argument('--logdir', default='log/', type=str,
#                         help='Logging path.', required=False)
#     parser.add_argument('--ckpdir', default='ckpt/', type=str,
#                         help='Checkpoint path.', required=False)
#     parser.add_argument('--outdir', default='result/', type=str,
#                         help='Decode output path.', required=False)
#     parser.add_argument('--load', default=None, type=str,
#                         help='Load pre-trained model (for training only)', required=False)
#     parser.add_argument('--seed', default=0, type=int,
#                         help='Random seed for reproducable results.', required=False)
#     parser.add_argument('--cudnn-ctc', action='store_true',
#                         help='Switches CTC backend from torch to cudnn')
#     parser.add_argument('--njobs', default=32, type=int,
#                         help='Number of threads for dataloader/decoding.', required=False)
#     parser.add_argument('--cpu', action='store_true', help='Disable GPU training.')
#     parser.add_argument('--no-pin', action='store_true',
#                         help='Disable pin-memory for dataloader')
#     parser.add_argument('--test', action='store_true', help='Test the model.')
#     parser.add_argument('--no-msg', action='store_true', help='Hide all messages.')
#     parser.add_argument('--lm', action='store_true',
#                         help='Option for training RNNLM.')
#     # Following features in development.
#     parser.add_argument('--amp', action='store_true', help='Option to enable AMP.')
#     parser.add_argument('--reserve-gpu', default=0, type=float,
#                         help='Option to reserve GPU ram for training.')
#     parser.add_argument('--jit', action='store_true',
#                         help='Option for enabling jit in pytorch. (feature in development)')
#     ###
#     paras = parser.parse_args()
    paras = Para()
#     paras.config = './config/aishell_asr_example_lstm4atthead1-test.yaml'
#     paras.name = None
#     paras.logdir = 'log/'
#     paras.ckpdir = 'ckpt/'
#     paras.outdir = 'result/'
#     paras.load = None
#     paras.seed = 0
#     paras.cudnn_ctc = False
#     paras.cpu = False
#     paras.no_pin = False
#     paras.test = True
#     paras.no_msg = False
#     paras.lm = False
#     paras.amp = False
#     paras.reserve_gpu = 0
#     paras.jit = False
    setattr(paras, 'config', './config/cv11Lu_asr_lstm4atthead_allvocab-biclass2.yaml')
    setattr(paras, 'name', None)
    setattr(paras, 'logdir', 'log/')
    setattr(paras, 'ckpdir', '/mnt/usb/jason3/LAS_ckpt')
    setattr(paras, 'outdir', 'result/')
    setattr(paras, 'load', './ckpt/mozillacv11_asr_stm4atthead_sd0/best_att.pth')
    setattr(paras, 'seed', 0)
    setattr(paras, 'cudnn_ctc', False)
    setattr(paras, 'njobs',8)
    setattr(paras, 'cpu', False)
    setattr(paras, 'no_pin', False)
    setattr(paras, 'test', False)
    setattr(paras, 'no_msg', False)
    setattr(paras, 'lm', False)
    setattr(paras, 'amp', False)
    setattr(paras, 'reserve_gpu', 9)
    setattr(paras, 'jit', False)
    setattr(paras, 'gpu', not paras.cpu)
    setattr(paras, 'pin_memory', not paras.no_pin)
    setattr(paras, 'verbose', not paras.no_msg)
    setattr(paras, 'finetune', False)
    setattr(paras, 'binaryClass', True)
#     force_cudnn_initialization()

    config = yaml.load(open(paras.config, 'r'), Loader=yaml.FullLoader)

    np.random.seed(paras.seed)
    torch.manual_seed(paras.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(paras.seed)

    # Hack to preserve GPU ram just incase OOM later on server
    if paras.gpu and paras.reserve_gpu > 0:
        buff = torch.randn(int(paras.reserve_gpu * 1e9 // 4)).cuda()
        del buff

    if paras.lm:
        # Train RNNLM
        from train_lm import Solver

        mode = 'train'
    else:
        if paras.test:
            # Test ASR
            assert paras.load is None, 'Load option is mutually exclusive to --test'
            from test_asr import Solver

            mode = 'test'
        elif paras.finetune:
            assert paras.load is not None
            from finetune_asr import Solver
            mode = 'train'
        elif paras.binaryClass:
            assert paras.load is not None
            from train_binaryclass2_5folds2 import Solver
            mode = 'train'
        else:
            # Train ASR
            from train_asr import Solver

            mode = 'train'

    print("\nUsing {} mode\n".format(mode))
    for idx in range(3,5):
        paras.config = f'./config/cv11Lu_asr_lstm4atthead_allvocab-biclass2-5fold-{idx+1}.yaml'#latest7k_4lstm.pth
#         setattr(paras, 'load', f'./ckpt/cv11Lu_asr_lstm4atthead_allvocab-biclass2-5fold-{idx+1}_sd0/latest13knew_4LSTM.pth')
        #要用vag01要改load_ckpt
        config = yaml.load(open(paras.config, 'r'), Loader=yaml.FullLoader)
        solver = Solver(config, paras, mode)

        solver.load_data()
    #     solver.print_model()
        solver.set_model()
        solver.exec()
        del solver
# Out:
# 0

# %%
main()
# Out:
# Using train mode
#
# [INFO] Exp. name : cv11Lu_asr_lstm4atthead_allvocab-biclass2-5fold-4_sd0
# [INFO] Loading data... large dataset may took a while.
# Load data for training/validation, store tokenizer and input/output shape
# Prepare dataloader for training/validation
# Interface for creating all kinds of dataset
# import VAGDataset as Dataset
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-4-2']
# Mozillacv11Dataset CTT5-4-2 found wav data: 17
# text len: 17
# remove None, then wav data: 17, text len: 17
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-1-2', 'CTT5-2-2', 'CTT5-3-2', 'CTT5-5-2']
# Mozillacv11Dataset CTT5-1-2 found wav data: 19
# Mozillacv11Dataset CTT5-2-2 found wav data: 18
# Mozillacv11Dataset CTT5-3-2 found wav data: 17
# Mozillacv11Dataset CTT5-5-2 found wav data: 17
# text len: 71
# remove None, then wav data: 71, text len: 71
# [INFO] Data spec. | Corpus = vag (from /home/jupyter-jason5/data_process)
# [INFO]            | Train sets = ['CTT5-1-2', 'CTT5-2-2', 'CTT5-3-2', 'CTT5-5-2']	| Number of utts = 71
# [INFO]            | Dev sets = ['CTT5-4-2']	| Number of utts = 17
# [INFO]            | Batch size = 1		| Bucketing = True
# [INFO] I/O spec.  | Audio feature = fbank	| feature dim = 120
# Setup ASR model and optimizer
# [INFO] Model spec.| Encoder's downsampling rate of time axis is 4.
# [INFO]            | VCC Extractor w/ time downsampling rate = 4 in encoder enabled.
# # Losses
# # Note: zero_infinity=False is unstable?
# # Optimizer
# [INFO] Optim.spec.| Algo. = Adadelta	| Lr = 1.0	 (Scheduler = fixed)| Scheduled sampling = False
# # Enable AMP if needed
# [INFO] Load ckpt from ./ckpt/mozillacv11_asr_stm4atthead_sd0/best_att.pth, restarting at step 1000000
# encoder.layers.0.extractor.0.weight
# encoder.layers.0.extractor.0.bias
# encoder.layers.4.layer.weight_ih_l0_reverse
# encoder.layers.4.layer.weight_hh_l0_reverse
# encoder.layers.4.layer.bias_ih_l0_reverse
# encoder.layers.4.layer.bias_hh_l0_reverse
# fc.weight
# fc.bias
# Training End-to-end ASR system
# [INFO] Total training steps 1.0K.
# self.tr_set: 71
# /home/jupyter-jason5/LAS_Mandarin_PyTorch-master/core/module.py:51: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   feat_len = feat_len // 4
# tensor(48.5475, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(47.5688, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(47.0475, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(46.4964, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(46.4149, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(45.9976, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(45.4763, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(44.8359, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(44.3743, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(43.7431, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(42.4278, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(41.3601, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(41.3099, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(40.2698, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(39.2815, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(37.6080, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(37.6832, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(35.9723, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(35.2589, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(34.8238, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(34.5417, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(34.0013, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(33.2990, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(31.7396, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(32.2565, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(31.4495, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(30.2249, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(29.3295, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(29.4089, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(27.9867, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(27.2197, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(27.0186, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(26.1040, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(24.9565, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(23.8613, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(21.2160, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(23.2566, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(20.6818, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(20.8416, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(19.4636, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(17.9513, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(17.5521, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(16.6389, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(16.2275, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(14.7091, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(14.6266, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(13.4645, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(13.0641, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(12.0240, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(11.1767, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(11.2149, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(10.6692, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.8380, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(9.0356, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(8.1380, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.6935, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.2178, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.2555, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.3013, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.8125, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.2578, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.5186, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.4271, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.2037, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.5810, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.3823, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.8909, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.7371, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.6956, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.4187, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.8082, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.5644, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.5449, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.3196, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.2025, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.3453, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.9360, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.9038, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.8250, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.7200, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.5697, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.5540, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6644, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.5520, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4251, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4785, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4302, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2813, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3054, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2484, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2417, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2737, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1963, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1567, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1836, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1452, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1539, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1276, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1181, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1036, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1037, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1002, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0833, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0829, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0748, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0668, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0604, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0599, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0555, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0466, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0477, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0402, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0444, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0399, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0406, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0328, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0347, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0308, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0308, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0290, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0278, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0287, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0246, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0230, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0234, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0229, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0211, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0174, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0193, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0175, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0162, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0169, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0166, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0151, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0145, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0145, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0134, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0129, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0129, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0122, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0122, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0112, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0105, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0118, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0106, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0096, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0092, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0091, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0080, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0085, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0085, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0076, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0079, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0041, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0040, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0037, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0036, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# 14001
# [INFO] Exp. name : cv11Lu_asr_lstm4atthead_allvocab-biclass2-5fold-5_sd0
# [INFO] Loading data... large dataset may took a while.
# Load data for training/validation, store tokenizer and input/output shape
# Prepare dataloader for training/validation
# Interface for creating all kinds of dataset
# import VAGDataset as Dataset
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-5-2']
# Mozillacv11Dataset CTT5-5-2 found wav data: 17
# text len: 17
# remove None, then wav data: 17, text len: 17
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-1-2', 'CTT5-2-2', 'CTT5-3-2', 'CTT5-4-2']
# Mozillacv11Dataset CTT5-1-2 found wav data: 19
# Mozillacv11Dataset CTT5-2-2 found wav data: 18
# Mozillacv11Dataset CTT5-3-2 found wav data: 17
# Mozillacv11Dataset CTT5-4-2 found wav data: 17
# text len: 71
# remove None, then wav data: 71, text len: 71
# [INFO] Data spec. | Corpus = vag (from /home/jupyter-jason5/data_process)
# [INFO]            | Train sets = ['CTT5-1-2', 'CTT5-2-2', 'CTT5-3-2', 'CTT5-4-2']	| Number of utts = 71
# [INFO]            | Dev sets = ['CTT5-5-2']	| Number of utts = 17
# [INFO]            | Batch size = 1		| Bucketing = True
# [INFO] I/O spec.  | Audio feature = fbank	| feature dim = 120
# Setup ASR model and optimizer
# [INFO] Model spec.| Encoder's downsampling rate of time axis is 4.
# [INFO]            | VCC Extractor w/ time downsampling rate = 4 in encoder enabled.
# # Losses
# # Note: zero_infinity=False is unstable?
# # Optimizer
# [INFO] Optim.spec.| Algo. = Adadelta	| Lr = 1.0	 (Scheduler = fixed)| Scheduled sampling = False
# # Enable AMP if needed
# [INFO] Load ckpt from ./ckpt/mozillacv11_asr_stm4atthead_sd0/best_att.pth, restarting at step 1000000
# encoder.layers.0.extractor.0.weight
# encoder.layers.0.extractor.0.bias
# encoder.layers.4.layer.weight_ih_l0_reverse
# encoder.layers.4.layer.weight_hh_l0_reverse
# encoder.layers.4.layer.bias_ih_l0_reverse
# encoder.layers.4.layer.bias_hh_l0_reverse
# fc.weight
# fc.bias
# Training End-to-end ASR system
# [INFO] Total training steps 1.0K.
# self.tr_set: 71
# tensor(48.5192, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(47.5199, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(47.5918, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(47.1311, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(47.0077, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(46.7618, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(46.4843, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(46.3277, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(45.7803, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(45.4852, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(44.8063, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(45.1841, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(44.7528, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(43.9541, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(43.6051, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(43.6673, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(41.7089, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(41.7739, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(42.0725, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(42.0935, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(41.6967, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(40.7161, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(41.2726, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(40.5033, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(40.5331, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(40.3007, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(40.0866, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(39.5573, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(38.5751, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(38.5591, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(37.5637, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(37.4517, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(37.9628, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(37.1022, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(37.0559, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(36.4343, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(35.9068, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(35.2591, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(34.0071, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(34.5901, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(32.8755, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(33.5064, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(31.9870, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(31.5019, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(31.0502, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(30.3076, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(28.1436, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(29.4449, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(28.7978, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(26.5468, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(26.6108, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(26.2905, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(20.7554, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(22.1204, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(21.9895, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(22.2223, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(19.0966, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(18.3092, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(18.6005, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(16.6513, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(17.7309, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(13.9542, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(14.7948, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(12.8009, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(13.7518, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(11.3903, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(11.2792, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(9.8739, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(9.9823, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(8.9535, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.0930, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.0787, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.7985, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.1082, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.5404, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.3117, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.6771, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.1841, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.7437, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.0687, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.6359, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.6206, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.5261, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.0633, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.8846, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.1665, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.3142, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.3783, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.6040, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.1812, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.1079, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.8613, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.9953, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.7552, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6120, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6733, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6139, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6591, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4096, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4220, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.5094, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3181, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3429, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3414, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2240, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2631, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2104, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1960, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1750, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1593, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1566, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1075, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1372, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1129, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0783, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1041, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0894, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0793, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0712, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0692, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0605, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0672, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0582, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0605, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0536, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0431, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0471, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0417, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0385, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0348, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0365, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0328, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0368, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0333, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0317, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0297, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0284, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0253, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0311, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0244, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0245, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0240, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0220, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0230, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0215, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0192, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0195, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0181, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0178, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0167, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0177, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0155, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0157, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0151, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0151, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0144, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0127, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0140, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0128, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0128, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0124, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0118, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0115, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0110, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0107, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0108, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0104, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0097, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0090, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0095, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0084, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0087, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0082, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0082, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0074, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0078, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0074, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# 14001

# %%
print('asd')

# %%
# !python eval.py --file ~/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv
# Out:
# ============  Result of /home/jupyter-jason3/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv ============
#  -----------------------------------------------------------------------
# | Statics		|  Truth	|  Prediction	| Abs. Diff.	|
#  -----------------------------------------------------------------------
# | Avg. # of chars	|  8.01	|  8.10	|  0.16		|
# | Avg. # of words	|  1.00	|  1.00	|  0.00		|
#  -----------------------------------------------------------------------
#  ---------------------------------------------------------------
# | Error Rate (%)| Mean		| Std.		| Min./Max.	|
#  ---------------------------------------------------------------
# | Character	| 7.9479	| 21.68		| 0.00/240.00	|
# | Word		| 18.1725	| 38.56		| 0.00/100.00	|
#  ---------------------------------------------------------------
# Note : If the text unit is phoneme, WER = PER and CER is meaningless.
