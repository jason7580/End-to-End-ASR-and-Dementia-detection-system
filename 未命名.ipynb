# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /opt/tljh/user/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.19.2)
# Collecting torchvision
#   Downloading torchvision-0.14.1-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 1.5 MB/s eta 0:00:01
# Collecting pytorch_pretrained_bert
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 50.3 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /opt/tljh/user/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (4.62.1)
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 51.7 MB/s eta 0:00:01
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      |████████████████████████████████| 840 kB 47.1 MB/s eta 0:00:01
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 50.0 MB/s eta 0:00:01
# Requirement already satisfied: pyyaml in /opt/tljh/user/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (5.4.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 50.7 MB/s eta 0:00:01
# Collecting tb-nightly
#   Downloading tb_nightly-2.12.0a20230113-py3-none-any.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 51.2 MB/s eta 0:00:01
# Collecting torch>=1.2.0
#   Downloading torch-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (887.5 MB)
#      |████████████████████████████████| 887.5 MB 28 kB/s s eta 0:00:013     |█████████████████████▍          | 591.9 MB 112.2 MB/s eta 0:00:03     |█████████████████████▌          | 595.7 MB 112.2 MB/s eta 0:00:03     |███████████████████████▊        | 656.5 MB 66.2 MB/s eta 0:00:04
# Collecting torchaudio
#   Downloading torchaudio-0.13.1-cp37-cp37m-manylinux1_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 49.6 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 51.8 MB/s eta 0:00:01
# Collecting editdistance
#   Downloading editdistance-0.6.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      |████████████████████████████████| 282 kB 48.4 MB/s eta 0:00:01
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      |████████████████████████████████| 557.1 MB 35 kB/s s eta 0:00:011   |████▋                           | 80.7 MB 66.1 MB/s eta 0:00:08
# Requirement already satisfied: typing-extensions in /opt/tljh/user/lib/python3.7/site-packages (from torch>=1.2.0->-r requirements.txt (line 11)) (3.10.0.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 49.9 MB/s eta 0:00:01
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      |████████████████████████████████| 317.1 MB 102 kB/s  eta 0:00:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 50.6 MB/s eta 0:00:01
# Requirement already satisfied: wheel in /opt/tljh/user/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.2.0->-r requirements.txt (line 11)) (0.36.2)
# Requirement already satisfied: setuptools in /opt/tljh/user/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.2.0->-r requirements.txt (line 11)) (52.0.0.post20210125)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 52.7 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 49.8 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 13)) (2.4.7)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 13)) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 13)) (8.3.1)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 13)) (21.0)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 13)) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/tljh/user/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 5)) (2021.1)
# Collecting boto3
#   Downloading boto3-1.26.135-py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 52.0 MB/s eta 0:00:01
# Collecting regex
#   Downloading regex-2023.5.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (756 kB)
#      |████████████████████████████████| 756 kB 51.2 MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/tljh/user/lib/python3.7/site-packages (from pytorch_pretrained_bert->-r requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/tljh/user/lib/python3.7/site-packages (from tb-nightly->-r requirements.txt (line 10)) (2.0.2)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 48.6 MB/s eta 0:00:01
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.54.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      |████████████████████████████████| 5.1 MB 44.9 MB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 5.4 MB/s  eta 0:00:01
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 48.6 MB/s eta 0:00:01
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 49.1 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 55.7 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<4,>=3.9.2 in /opt/tljh/user/lib/python3.7/site-packages (from tb-nightly->-r requirements.txt (line 10)) (3.15.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/tljh/user/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 10)) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/tljh/user/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 10)) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/tljh/user/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 10)) (4.2.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/tljh/user/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tb-nightly->-r requirements.txt (line 10)) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/tljh/user/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly->-r requirements.txt (line 10)) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/tljh/user/lib/python3.7/site-packages (from requests->pytorch_pretrained_bert->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/tljh/user/lib/python3.7/site-packages (from requests->pytorch_pretrained_bert->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.7/site-packages (from requests->pytorch_pretrained_bert->-r requirements.txt (line 3)) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/tljh/user/lib/python3.7/site-packages (from requests->pytorch_pretrained_bert->-r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/tljh/user/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tb-nightly->-r requirements.txt (line 10)) (3.1.0)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 73.0 MB/s eta 0:00:01
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 24.5 MB/s eta 0:00:01
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.30.0,>=1.29.135
#   Downloading botocore-1.29.135-py3-none-any.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 51.5 MB/s eta 0:00:01
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492026 sha256=c852eabb27228e2f27d1ab1e3bbcebf18b20c81ff659cdca61d27dea0f2e4dd0
#   Stored in directory: /home/jupyter-jason4/.cache/pip/wheels/fa/cd/1f/c6b7b50b564983bf3011e8fc75d06047ddc50c07f6e3660b00
# Successfully built future
# Installing collected packages: jmespath, nvidia-cublas-cu11, botocore, s3transfer, requests-oauthlib, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, MarkupSafe, importlib-metadata, werkzeug, torch, tensorboard-plugin-wit, tensorboard-data-server, regex, pillow, markdown, kiwisolver, grpcio, google-auth-oauthlib, fonttools, cycler, boto3, absl-py, torchvision, torchaudio, tb-nightly, sentencepiece, pytorch-pretrained-bert, pandas, matplotlib, joblib, future, editdistance
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/home/jupyter-jason4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py is installed in '/home/jupyter-jason4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool is installed in '/home/jupyter-jason4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/jupyter-jason4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/home/jupyter-jason4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pytorch_pretrained_bert is installed in '/home/jupyter-jason4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts futurize and pasteurize are installed in '/home/jupyter-jason4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed MarkupSafe-2.1.2 absl-py-1.4.0 boto3-1.26.135 botocore-1.29.135 cycler-0.11.0 editdistance-0.6.2 fonttools-4.38.0 future-0.18.3 google-auth-oauthlib-0.4.6 grpcio-1.54.2 importlib-metadata-6.6.0 jmespath-1.0.1 joblib-1.2.0 kiwisolver-1.4.4 markdown-3.4.3 matplotlib-3.5.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 pandas-1.3.5 pillow-9.5.0 pytorch-pretrained-bert-0.6.2 regex-2023.5.5 requests-oauthlib-1.3.1 s3transfer-0.6.1 sentencepiece-0.1.99 tb-nightly-2.12.0a20230113 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 torch-1.13.1 torchaudio-0.13.1 torchvision-0.14.1 werkzeug-2.2.3

# %%
#! python
# -*- coding: utf-8 -*-
# Author: kun
# @Time: 2019-10-29 20:29

import yaml
import torch
import argparse
import numpy as np

class Para(object):
    a=1

def force_cudnn_initialization():
    s = 32
    dev = torch.device('cuda')
    torch.nn.functional.conv2d(torch.zeros(s, s, s, s, device=dev), torch.zeros(s, s, s, s, device=dev))
    
#force_cudnn_initialization()
def main():
    # For reproducibility, comment these may speed up training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Arguments
#     parser = argparse.ArgumentParser(description='Training E2E asr.')
#     parser.add_argument('--config', type=str, help='Path to experiment config.')
#     parser.add_argument('--name', default=None, type=str, help='Name for logging.')
#     parser.add_argument('--logdir', default='log/', type=str,
#                         help='Logging path.', required=False)
#     parser.add_argument('--ckpdir', default='ckpt/', type=str,
#                         help='Checkpoint path.', required=False)
#     parser.add_argument('--outdir', default='result/', type=str,
#                         help='Decode output path.', required=False)
#     parser.add_argument('--load', default=None, type=str,
#                         help='Load pre-trained model (for training only)', required=False)
#     parser.add_argument('--seed', default=0, type=int,
#                         help='Random seed for reproducable results.', required=False)
#     parser.add_argument('--cudnn-ctc', action='store_true',
#                         help='Switches CTC backend from torch to cudnn')
#     parser.add_argument('--njobs', default=32, type=int,
#                         help='Number of threads for dataloader/decoding.', required=False)
#     parser.add_argument('--cpu', action='store_true', help='Disable GPU training.')
#     parser.add_argument('--no-pin', action='store_true',
#                         help='Disable pin-memory for dataloader')
#     parser.add_argument('--test', action='store_true', help='Test the model.')
#     parser.add_argument('--no-msg', action='store_true', help='Hide all messages.')
#     parser.add_argument('--lm', action='store_true',
#                         help='Option for training RNNLM.')
#     # Following features in development.
#     parser.add_argument('--amp', action='store_true', help='Option to enable AMP.')
#     parser.add_argument('--reserve-gpu', default=0, type=float,
#                         help='Option to reserve GPU ram for training.')
#     parser.add_argument('--jit', action='store_true',
#                         help='Option for enabling jit in pytorch. (feature in development)')
#     ###
#     paras = parser.parse_args()
    paras = Para()
#     paras.config = './config/aishell_asr_example_lstm4atthead1-test.yaml'
#     paras.name = None
#     paras.logdir = 'log/'
#     paras.ckpdir = 'ckpt/'
#     paras.outdir = 'result/'
#     paras.load = None
#     paras.seed = 0
#     paras.cudnn_ctc = False
#     paras.cpu = False
#     paras.no_pin = False
#     paras.test = True
#     paras.no_msg = False
#     paras.lm = False
#     paras.amp = False
#     paras.reserve_gpu = 0
#     paras.jit = False
    setattr(paras, 'config', './config/aishell_asr_example_lstm4atthead1-test.yaml')
    setattr(paras, 'name', None)
    setattr(paras, 'logdir', 'log/')
    setattr(paras, 'ckpdir', 'ckpt/')
    setattr(paras, 'outdir', 'result/')
    setattr(paras, 'load', None)
    setattr(paras, 'seed', 0)
    setattr(paras, 'cudnn_ctc', False)
    setattr(paras, 'njobs', 8)
    setattr(paras, 'cpu', False)
    setattr(paras, 'no_pin', False)
    setattr(paras, 'test', True)
    setattr(paras, 'no_msg', False)
    setattr(paras, 'lm', False)
    setattr(paras, 'amp', False)
    setattr(paras, 'reserve_gpu', False)
    setattr(paras, 'jit', False)
    setattr(paras, 'gpu', not paras.cpu)
    setattr(paras, 'pin_memory', not paras.no_pin)
    setattr(paras, 'verbose', not paras.no_msg)
    

    config = yaml.load(open(paras.config, 'r'), Loader=yaml.FullLoader)

    np.random.seed(paras.seed)
    torch.manual_seed(paras.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(paras.seed)

    # Hack to preserve GPU ram just incase OOM later on server
    if paras.gpu and paras.reserve_gpu > 0:
        buff = torch.randn(int(paras.reserve_gpu * 1e9 // 4)).cuda()
        del buff

    if paras.lm:
        # Train RNNLM
        from train_lm import Solver

        mode = 'train'
    else:
        if paras.test:
            # Test ASR
            assert paras.load is None, 'Load option is mutually exclusive to --test'
            from test_asr import Solver

            mode = 'test'
        else:
            # Train ASR
            from train_asr import Solver

            mode = 'train'

    print("\nUsing {} mode\n".format(mode))
    solver = Solver(config, paras, mode)
    solver.load_data()
    solver.set_model()
    solver.exec()

# %%
main()
# Out:
# Using test mode
#
# [INFO] Evaluating result of tr. config @ ../LAS_Mandarin_PyTorch-master/config/aishell_asr_example_lstm4atthead1.yaml
# Prepare dataloader for training/validation
# Load text encoder : CharacterTextEncoder
# Interface for creating all kinds of dataset
# import AishellDataset as Dataset
# [AishellDataset] path: /mnt/usb/jason/data_aishell/wav, split: ['dev']
# AishellDataset dev found wav data: 14331
# text len: 14331
# remove None, then wav data: 14326, text len: 14326
# [AishellDataset] path: /mnt/usb/jason/data_aishell/wav, split: ['test']
# AishellDataset test found wav data: 7176
# text len: 7176
# remove None, then wav data: 7176, text len: 7176
# [INFO] Data spec. | Corpus = aishell (from /mnt/usb/jason/data_aishell/wav)
# [INFO]            | Dev sets = ['dev']	| Number of utts = 14326
# [INFO]            | Test sets = ['test']	| Number of utts = 7176
# [INFO]            | Batch size = 1		| Bucketing = False
# [INFO] I/O spec.  | Audio feature = fbank	| feature dim = 120	| Token type = character	| Vocab size = 4337
# [INFO] Evaluation target = ../best_att-0.1603051739870937.pth (recorded wer = 0.16 %)
# [INFO] Decode spec| Beam size = 2	| Min/Max len ratio = 0.0/10.0
# [INFO] Performing instance-wise beam decoding on dev set. (NOTE: use --njobs to speedup)
#   0%|          | 16/14326 [04:02<73:27:32, 18.48s/it]/home/jupyter-jason/.local/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:703: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
#   1%|          | 136/14326 [1:01:43<86:26:44, 21.93s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-2-c61b35cd5381> in main()
#     129     solver.load_data()
#     130     solver.set_model()
# --> 131     solver.exec()
#
# ~/LAS_Mandarin_PyTorch-master/test_asr.py in exec(self)
#     104                 # Parallel beam decode
#     105                 results = Parallel(n_jobs=self.paras.njobs)(
# --> 106                     delayed(beam_decode_func)(data) for data in tqdm(ds))
#     107                 self.verbose(
#     108                     'Results/Beams will be stored at {} / {}.'.format(self.cur_output_path, self.cur_beam_path))
#
# ~/.local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~/.local/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /opt/tljh/user/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/tljh/user/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-6-85ba4973bfbb> in <module>
# ----> 1 start()
#
# <ipython-input-5-bac1f76c2041> in start()
#      52                         help='Option for enabling jit in pytorch. (feature in development)')
#      53     ###
# ---> 54     paras = parser.parse_args()
#      55
#      56     paras.config = './config/aishell_asr_example_lstm4atthead1-test.yaml'
#
# /opt/tljh/user/lib/python3.7/argparse.py in parse_args(self, args, namespace)
#    1756         if argv:
#    1757             msg = _('unrecognized arguments: %s')
# -> 1758             self.error(msg % ' '.join(argv))
#    1759         return args
#    1760
#
# /opt/tljh/user/lib/python3.7/argparse.py in error(self, message)
#    2506         self.print_usage(_sys.stderr)
#    2507         args = {'prog': self.prog, 'message': message}
# -> 2508         self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# /opt/tljh/user/lib/python3.7/argparse.py in exit(self, status, message)
#    2493         if message:
#    2494             self._print_message(message, _sys.stderr)
# -> 2495         _sys.exit(status)
#    2496
#    2497     def error(self, message):
#
# SystemExit: 2

# %%
with open("aabc.txt", "a") as attfile:
        attfile.write('abcc')
