# %%
# !export CUDA_VISIBLE_DEVICES=0

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
# os.environ['CUDA_VISIBLE_DEVICES']='0,1'
os.environ['CUDA_LAUNCH_BLOCKING']='1'
import torch
# torch.cuda.set_device(0)
print(torch.cuda.current_device())
# Out:
# 0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
# cudaSetDevice(0)
#dataset transcript要在dataset資好夾調
#cuda 在basesolver init調
#dataset要在data.py設定
#text 裏面tokenizer 要把s[0]改回s

# %%
#! python
# -*- coding: utf-8 -*-
# Author: kun
# @Time: 2019-10-29 20:29

import yaml
import torch
import argparse
import numpy as np

class Para(object):
    a=1

def force_cudnn_initialization():
    s = 32
    dev = torch.device('cuda:0')
    torch.nn.functional.conv2d(torch.zeros(s, s, s, s, device=dev), torch.zeros(s, s, s, s, device=dev))
    
#force_cudnn_initialization()
def main():
    # For reproducibility, comment these may speed up training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Arguments
#     parser = argparse.ArgumentParser(description='Training E2E asr.')
#     parser.add_argument('--config', type=str, help='Path to experiment config.')
#     parser.add_argument('--name', default=None, type=str, help='Name for logging.')
#     parser.add_argument('--logdir', default='log/', type=str,
#                         help='Logging path.', required=False)
#     parser.add_argument('--ckpdir', default='ckpt/', type=str,
#                         help='Checkpoint path.', required=False)
#     parser.add_argument('--outdir', default='result/', type=str,
#                         help='Decode output path.', required=False)
#     parser.add_argument('--load', default=None, type=str,
#                         help='Load pre-trained model (for training only)', required=False)
#     parser.add_argument('--seed', default=0, type=int,
#                         help='Random seed for reproducable results.', required=False)
#     parser.add_argument('--cudnn-ctc', action='store_true',
#                         help='Switches CTC backend from torch to cudnn')
#     parser.add_argument('--njobs', default=32, type=int,
#                         help='Number of threads for dataloader/decoding.', required=False)
#     parser.add_argument('--cpu', action='store_true', help='Disable GPU training.')
#     parser.add_argument('--no-pin', action='store_true',
#                         help='Disable pin-memory for dataloader')
#     parser.add_argument('--test', action='store_true', help='Test the model.')
#     parser.add_argument('--no-msg', action='store_true', help='Hide all messages.')
#     parser.add_argument('--lm', action='store_true',
#                         help='Option for training RNNLM.')
#     # Following features in development.
#     parser.add_argument('--amp', action='store_true', help='Option to enable AMP.')
#     parser.add_argument('--reserve-gpu', default=0, type=float,
#                         help='Option to reserve GPU ram for training.')
#     parser.add_argument('--jit', action='store_true',
#                         help='Option for enabling jit in pytorch. (feature in development)')
#     ###
#     paras = parser.parse_args()
    paras = Para()
#     paras.config = './config/aishell_asr_example_lstm4atthead1-test.yaml'
#     paras.name = None
#     paras.logdir = 'log/'
#     paras.ckpdir = 'ckpt/'
#     paras.outdir = 'result/'
#     paras.load = None
#     paras.seed = 0
#     paras.cudnn_ctc = False
#     paras.cpu = False
#     paras.no_pin = False
#     paras.test = True
#     paras.no_msg = False
#     paras.lm = False
#     paras.amp = False
#     paras.reserve_gpu = 0
#     paras.jit = False
    setattr(paras, 'config', './config/cv11Lu_asr_lstm4atthead.yaml')
    setattr(paras, 'name', None)
    setattr(paras, 'logdir', 'log/')
    setattr(paras, 'ckpdir', 'ckpt/')
    setattr(paras, 'outdir', 'result/')
    setattr(paras, 'load', None)
    setattr(paras, 'seed', 0)
    setattr(paras, 'cudnn_ctc', False)
    setattr(paras, 'njobs',8)
    setattr(paras, 'cpu', False)
    setattr(paras, 'no_pin', False)
    setattr(paras, 'test', False)
    setattr(paras, 'no_msg', False)
    setattr(paras, 'lm', False)
    setattr(paras, 'amp', False)
    setattr(paras, 'reserve_gpu', 0)
    setattr(paras, 'jit', False)
    setattr(paras, 'gpu', not paras.cpu)
    setattr(paras, 'pin_memory', not paras.no_pin)
    setattr(paras, 'verbose', not paras.no_msg)
    force_cudnn_initialization()

    config = yaml.load(open(paras.config, 'r'), Loader=yaml.FullLoader)

    np.random.seed(paras.seed)
    torch.manual_seed(paras.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(paras.seed)

    # Hack to preserve GPU ram just incase OOM later on server
    if paras.gpu and paras.reserve_gpu > 0:
        buff = torch.randn(int(paras.reserve_gpu * 1e9 // 4)).cuda()
        del buff

    if paras.lm:
        # Train RNNLM
        from train_lm import Solver

        mode = 'train'
    else:
        if paras.test:
            # Test ASR
            assert paras.load is None, 'Load option is mutually exclusive to --test'
            from test_asr import Solver

            mode = 'test'
        else:
            # Train ASR
            from train_asr import Solver

            mode = 'train'

    print("\nUsing {} mode\n".format(mode))
    solver = Solver(config, paras, mode)
    solver.load_data()
    solver.set_model()
    solver.exec()

# %%
main()
# Out:
# Using train mode
#
# [INFO] Exp. name : cv11Lu_asr_lstm4atthead_sd0
# [INFO] Loading data... large dataset may took a while.
# Load data for training/validation, store tokenizer and input/output shape
# Prepare dataloader for training/validation
# Load text encoder : CharacterTextEncoder
# Interface for creating all kinds of dataset
# import Mozillacv11Dataset as Dataset
# [Mozillacv11Dataset] path: /mnt/usb/jason3/cv-corpus-11.0-2022-09-21/zh-TW/wavs, split: ['dev']
# Mozillacv11Dataset dev found wav data: 14709
# text len: 14709
# remove None, then wav data: 14709, text len: 14709
# ['以前瞻的視野縝密規劃', '晚上都作夢到哭', '保存著他們的記憶', '說明定錨的重要性', '客廳都沒開燈', '我們決定工作職掌', '若沒被記錄下來', '外婆格外沉默', '新店家樂福要開始動工嘍', '有時需要用錢', '問過身邊的人', '開會程序', '注視著你的一點機會', '竹東二交流道', '將成為一大關鍵', '台灣的一條省道', '游泳去與那國島', '高雄市和平路', '正大路', '碧興路', '台北廣州街', '臺中市的環狀快速公路', '網路系統還不夠穩定', '兩岸過去二十多年來', '中央街', '工商時間', '什麼是最佳的渡假方式', '漢寶交流道', '帶領大軍追擊匈奴', '辛亥革命爆發', '算是公開的秘密吧', '苗栗南橫公路', '精誠路', '有關元素及原子的概念', '恨啊', '或編輯物', '無理數或無限小數', '高雄捷運東港延伸線', '向上路', '生產的數量', '誰有需要嗎', '想不到更好的時機了', '這些財政上的改革', '描述一個親身的經驗', '耕種和畜牧的主要分界', '更是倉卒策畫', '圖是橫紋肌示意圖', '測燈泡的電阻', '電流無法流通', '出國旅遊蔚成風氣', '愈來愈大', '挑戰不可能', '企業投資', '第十四任總統與副總統', '有一首歌曲', '維持兩岸關係的和平穩定', '我們將和相關的各方', '在這裡我要誠懇地呼籲', '這個國家的主人', '我會讓大家看到', '我們會嚴格把關', '及國民健康', '就必須從現在起就下定決心', '也要讓世界走進臺灣', '更不要失去信心', '應該做自己想做的事', '每當我打著文章時', '聽說北港有個人', '眾人呆站在外', '直銷的東西', '新北市淡水區中正路一段', '中國人說還要十幾分鐘', '忙得要死她動怒了', '把可能產生的損害降到最低', '職涯探索職場學習', '螢幕上白色游標閃爍刺眼', '年紀大了難免有病', '迎向健康希望的每一天', '為什麼你最近晚上都作夢', '小的果然太弱', '還是再度找上門', '以前自己對她很不好', '如果不這麼解釋', '看了兩本很有興趣的書', '他日我們必當湧泉以報', '剛好在吃飯時遇到', '臉書社團的管理者', '感覺可以住一天', '當然只能買最便宜的', '說沒撿到', '到了車站', '因為還是人要使用的', '就事實觀之', '不要為了程序問題', '似乎百分之九十為專業人士', '也能藉由輿論力量予以化解', '在前人的基礎上', '官方及非官方', '新莊地區', '相對嚴峻', '主席副主席', '契約終止三個月後', '基本上這是一個體制外的會議', '明天放學後有要練習嗎', '快到了', '廣納各住戶之意見', '苗栗幅員遼闊', '時代不停進步', '繁衍後代', '參閱書面資料', '我們家應該沒有', '會確認後續的處理流程', '積極作為', '情人節要到了', '我們原則都會同意', '考評優等', '各系統經營者', '現在的民主', '各位碰過嗎', '舊美濃橋', '水沙連高速公路', '一九九八年', '手機號碼載具跟自然人憑證', '太原路', '台中市神岡區圳前里', '臉書廣告的方法比較好', '香港人到台灣旅遊', '肯定有人可以聊聊', '第一代南方澳大橋', '運動社團', '但是燈打上去很漂亮', '我就真的不會去嗎', '他的回答令她十分震驚', '開口比較寬', '不刺激不示弱不動氣', '他的身影逐漸模糊', '一早六點就起床', '國泰世紀產物保險', '她也放聲大哭', '希望開拓海外商機', '積極推動創業政策', '一間公司變好', '到了終點', '雖然買之前就知道', '新北市淡水區中正路一段', '對我來說都是最珍貴的意見', '共享經濟成長的果實', '努力想做好那份工作', '另一方面另行謀職', '是什麼意思', '無助的他們馬上趕過去', '今天的七星山讚', '對她有什麼偏見或不滿', '住在台北的大舅家', '完全不尊重他', '年輕人可以搬出去住了', '所以不是不做審查', '很多人都是當了父母', '投入試種', '所以要求縣市議員申報', '一昧地說都是別人的錯', '以及預算問題', '與惡的距離', '來養一個殺人魔', '才開始學會當父母', '用一種很怪的方式封住了自己的能力', '相關改建資料', '世代之間時常意見相左', '大多將參與者分為正反雙方', '聽到旁邊的人在說', '期望透過這個行動打破政治上的限制', '身上總像背著什麼', '讓所有人可以一起來努力', '幫忙家裡插秧', '不行不能放棄', '每次幾乎都會碰上', '颱風一來', '進行調查解決問題', '在日落之前完成', '小時候過年山上很涼', '想說再把錢贏回來', '符合臺北市的產業型態', '思索著如何料理晚餐', '連他的名字都不知道', '要坐在右側才可以看海', '就差當天沒直接訂', '五十歲時中風前', '我要和阿嬤一起去', '協助婦女再就業', '才會去處理機車問題', '我們現在聊天', '她每天早出晚歸', '一切又充滿了希望', '看到過幾株特別大特別燦爛的麥穗', '奧迪創速中心', '預計要花兩年的時間', '人造器官當然搶手', '也有很多解決克服的方法', '安靜的氣氛', '我覺得很不錯的解釋', '結果就一共買了三本', '我看到舊的資料', '看了朋友拍的台東熱氣球照片', '只是遇到亂流而已', '將透過願景計畫建立平臺', '之後就沒有了', '他昨天才知道該', '只有一種人我絕對不會給他半毛錢', '簡單講就是時間不足', '連入睡的表情都是笑著的', '流動的程度不要太高', '我還是無法離開', '心理微微不悅', '我還以為自由席會沒位子', '主動開放空間給災民使用', '公車還要再等五十分鐘', '再度生下小女嬰', '我覺得麥當勞不便宜', '但是這實在不可能', '肯定骨折或需要開刀', '目前仍然在公告初選收件階段', '能夠跨越任期', '跟我到天國去吧', '可以先辦帳號', '故丁球先著地', '向家鄉父老炫耀', '深得寵信的經過', '灌溉便利', '機率會比較好', '積極侵略北非及東非時', '是綁台新信用卡', '政治上分立為十六個國家', '只要鞏固了民族主義', '那麼大的東西', '高空煙火', '免收使用費及保證金', '不要急著搶麥克風', '以嶄新的面貌再生', '一步一腳印展現成果', '真的很沮喪', '也是臺灣電影人的家', '同性別之監護人', '其他各組有無補充報告', '民意調查', '對此完全沒有預設立場', '我們做了什麼改變了什麼', '真是太貼心了', '新開闢公園', '跟連線數點擊方式', '賦稅署與國稅局', '打是情罵是愛不打不罵是變態', '比如車馬費這一類的', '看是否能克服', '但是已前面經花了三十分鐘', '千金難買蚤不到', '那個幾乎是不可能的事情', '嘻嘻哈哈嘻嘻不好笑', '上次有幾個教授來', '世上只有媽媽好有媽的孩子像漢堡', '當然會有一段時間需要學習', '古道梅子綠茶附近地方媽媽', '如果載具都有歸戶', '做為遊戲化的參考', '現在的苗栗國', '真厲害', '就算原本的設計再美', '都要移到替代的大樓', '不打勾時', '我上面寫的文字就說很遠', '這是一隻間諜', '刷載具的速度', '箭在弓弦上', '是', '來了來了', '盲目的信賴導致毀滅', '監察院政治獻金公開查閱平臺', '以上皆是', '喝個酒下去', '就一直傳假消息', '壁咚寡婦', '蜘蛛恐怕是最愛架網的物種', '宜蘭礁溪', '但是這陣子發現', '那合作就只是合作', '用盡量小的門檻', '一面倒的壓榨和欺凌', '這台機器涼了你熱了我', '今天的每日一句', '明明就是相信', '有良心的燒臘店', '用三條繩子就可以移動', '聽說蘇軾很喜歡吃豬背脂', '火狐狸瀏覽器', '上次來這家公司', '然後不成的話', '雖然沒這份文件', '卻不能拯救你', '我想要的是', '不知道實際的授權是哪個', '二零二五年', '不想用第三方的話', '跟中共講好', '一支穿雲箭', '後來在討論', '疑你嗎', '會不會只是用錯了感官', '希望就乖乖的用就好', '我做了一個影片教學', '站

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-6-d41b7882abd6> in main()
#     127     print("\nUsing {} mode\n".format(mode))
#     128     solver = Solver(config, paras, mode)
# --> 129     solver.load_data()
#     130     solver.set_model()
#     131     solver.exec()
#
# ~/LAS_Mandarin_PyTorch-master/train_asr.py in load_data(self)
#      37         self.tr_set, self.dv_set, self.feat_dim, self.vocab_size, self.tokenizer, msg = \
#      38             load_dataset(self.paras.njobs, self.paras.gpu, self.paras.pin_memory,
# ---> 39                          self.curriculum > 0, **self.config['data'])
#      40         self.verbose(msg)
#      41
#
# ~/LAS_Mandarin_PyTorch-master/core/data.py in load_dataset(n_jobs, use_gpu, pin_memory, ascending, corpus, audio, text)
#     162     # Dataset (in testing mode, tr_set=dv_set, dv_set=tt_set)
#     163     tr_set, dv_set, tr_loader_bs, dv_loader_bs, mode, data_msg = create_dataset(
# --> 164         tokenizer, ascending, **corpus)
#     165     # Collect function
#     166     collect_tr = partial(collect_audio_batch,
#
# ~/LAS_Mandarin_PyTorch-master/core/data.py in create_dataset(tokenizer, ascending, name, path, bucketing, batch_size, train_split, dev_split, test_split)
#      99         dv_set = Dataset(path, dev_split, tokenizer, 1)
#     100         tr_set = Dataset(path, train_split, tokenizer,
# --> 101                          bucket_size, ascending=ascending)
#     102         # Messages to show
#     103         msg_list = _data_msg(name, path, train_split.__str__(), len(tr_set),
#
# ~/LAS_Mandarin_PyTorch-master/dataset/mozilla_cv11.py in __init__(self, path, split, tokenizer, bucket_size, ascending)
#      74         # Read text
#      75         text = Parallel(n_jobs=READ_FILE_THREADS)(
# ---> 76             delayed(read_text)(str(f)) for f in file_list)
#      77         # text = []
#      78         # for f in file_list:
#
# ~/.local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~/.local/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /opt/tljh/user/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/tljh/user/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
print('asd')

# %%
# !python eval.py --file ~/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv
# Out:
# ============  Result of /home/jupyter-jason3/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv ============
#  -----------------------------------------------------------------------
# | Statics		|  Truth	|  Prediction	| Abs. Diff.	|
#  -----------------------------------------------------------------------
# | Avg. # of chars	|  8.01	|  8.10	|  0.16		|
# | Avg. # of words	|  1.00	|  1.00	|  0.00		|
#  -----------------------------------------------------------------------
#  ---------------------------------------------------------------
# | Error Rate (%)| Mean		| Std.		| Min./Max.	|
#  ---------------------------------------------------------------
# | Character	| 7.9479	| 21.68		| 0.00/240.00	|
# | Word		| 18.1725	| 38.56		| 0.00/100.00	|
#  ---------------------------------------------------------------
# Note : If the text unit is phoneme, WER = PER and CER is meaningless.
