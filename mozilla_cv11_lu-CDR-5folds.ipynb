# %%
# !export CUDA_VISIBLE_DEVICES=0

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'
# os.environ['CUDA_VISIBLE_DEVICES']='0,1'
os.environ['CUDA_LAUNCH_BLOCKING']='1'
import torch
# torch.cuda.set_device(0)
print(torch.cuda.current_device())
# Out:
# 0

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
# cudaSetDevice(0)
#dataset transcript要在dataset資好夾調
#cuda 在basesolver init調
#dataset要在data.py設定

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
# os.environ['CUDA_VISIBLE_DEVICES']='0,1'
os.environ['CUDA_LAUNCH_BLOCKING']='1'
import torch
# torch.cuda.set_device(0)
print(torch.cuda.current_device())
#! python
# -*- coding: utf-8 -*-
# Author: kun
# @Time: 2019-10-29 20:29

import yaml
import torch
import argparse
import numpy as np

class Para(object):
    a=1

def force_cudnn_initialization():
    s = 32
    dev = torch.device('cuda:0')
    torch.nn.functional.conv2d(torch.zeros(s, s, s, s, device=dev), torch.zeros(s, s, s, s, device=dev))
    
#force_cudnn_initialization()
def main():
    # For reproducibility, comment these may speed up training
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

    # Arguments
#     parser = argparse.ArgumentParser(description='Training E2E asr.')
#     parser.add_argument('--config', type=str, help='Path to experiment config.')
#     parser.add_argument('--name', default=None, type=str, help='Name for logging.')
#     parser.add_argument('--logdir', default='log/', type=str,
#                         help='Logging path.', required=False)
#     parser.add_argument('--ckpdir', default='ckpt/', type=str,
#                         help='Checkpoint path.', required=False)
#     parser.add_argument('--outdir', default='result/', type=str,
#                         help='Decode output path.', required=False)
#     parser.add_argument('--load', default=None, type=str,
#                         help='Load pre-trained model (for training only)', required=False)
#     parser.add_argument('--seed', default=0, type=int,
#                         help='Random seed for reproducable results.', required=False)
#     parser.add_argument('--cudnn-ctc', action='store_true',
#                         help='Switches CTC backend from torch to cudnn')
#     parser.add_argument('--njobs', default=32, type=int,
#                         help='Number of threads for dataloader/decoding.', required=False)
#     parser.add_argument('--cpu', action='store_true', help='Disable GPU training.')
#     parser.add_argument('--no-pin', action='store_true',
#                         help='Disable pin-memory for dataloader')
#     parser.add_argument('--test', action='store_true', help='Test the model.')
#     parser.add_argument('--no-msg', action='store_true', help='Hide all messages.')
#     parser.add_argument('--lm', action='store_true',
#                         help='Option for training RNNLM.')
#     # Following features in development.
#     parser.add_argument('--amp', action='store_true', help='Option to enable AMP.')
#     parser.add_argument('--reserve-gpu', default=0, type=float,
#                         help='Option to reserve GPU ram for training.')
#     parser.add_argument('--jit', action='store_true',
#                         help='Option for enabling jit in pytorch. (feature in development)')
#     ###
#     paras = parser.parse_args()
    paras = Para()
#     paras.config = './config/aishell_asr_example_lstm4atthead1-test.yaml'
#     paras.name = None
#     paras.logdir = 'log/'
#     paras.ckpdir = 'ckpt/'
#     paras.outdir = 'result/'
#     paras.load = None
#     paras.seed = 0
#     paras.cudnn_ctc = False
#     paras.cpu = False
#     paras.no_pin = False
#     paras.test = True
#     paras.no_msg = False
#     paras.lm = False
#     paras.amp = False
#     paras.reserve_gpu = 0
#     paras.jit = False
    setattr(paras, 'config', './config/cv11Lu_asr_lstm4atthead_allvocab-biclass2.yaml')
    setattr(paras, 'name', None)
    setattr(paras, 'logdir', 'log/')
    setattr(paras, 'ckpdir', '/mnt/usb/jason3/LAS_ckpt')
    setattr(paras, 'outdir', 'result/')
    setattr(paras, 'load', './ckpt/cv11Lu_asr_lstm4atthead_allvocab_sd0/best_att-VAG01.pth')
    setattr(paras, 'seed', 0)
    setattr(paras, 'cudnn_ctc', False)
    setattr(paras, 'njobs',8)
    setattr(paras, 'cpu', False)
    setattr(paras, 'no_pin', False)
    setattr(paras, 'test', False)
    setattr(paras, 'no_msg', False)
    setattr(paras, 'lm', False)
    setattr(paras, 'amp', False)
    setattr(paras, 'reserve_gpu', 9)
    setattr(paras, 'jit', False)
    setattr(paras, 'gpu', not paras.cpu)
    setattr(paras, 'pin_memory', not paras.no_pin)
    setattr(paras, 'verbose', not paras.no_msg)
    setattr(paras, 'finetune', False)
    setattr(paras, 'binaryClass', True)
    force_cudnn_initialization()

    config = yaml.load(open(paras.config, 'r'), Loader=yaml.FullLoader)

    np.random.seed(paras.seed)
    torch.manual_seed(paras.seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(paras.seed)

    # Hack to preserve GPU ram just incase OOM later on server
    if paras.gpu and paras.reserve_gpu > 0:
        buff = torch.randn(int(paras.reserve_gpu * 1e9 // 4)).cuda()
        del buff

    if paras.lm:
        # Train RNNLM
        from train_lm import Solver

        mode = 'train'
    else:
        if paras.test:
            # Test ASR
            assert paras.load is None, 'Load option is mutually exclusive to --test'
            from test_asr import Solver

            mode = 'test'
        elif paras.finetune:
            assert paras.load is not None
            from finetune_asr import Solver
            mode = 'train'
        elif paras.binaryClass:
            assert paras.load is not None
            from train_CDR_5folds import Solver
            mode = 'train'
        else:
            # Train ASR
            from train_asr import Solver

            mode = 'train'

    print("\nUsing {} mode\n".format(mode))
    for idx in range(2,5):
        paras.config = f'./config/cv11Lu_asr_lstm4atthead_allvocab-CDR-5fold-{idx+1}.yaml'
#         setattr(paras, 'load', f'./ckpt/cv11Lu_asr_lstm4atthead_allvocab-biclass2-5fold-{idx+1}_sd0/latest10knew_1VGG_4LSTM.pth')

        config = yaml.load(open(paras.config, 'r'), Loader=yaml.FullLoader)
        solver = Solver(config, paras, mode)

        solver.load_data()
    #     solver.print_model()
        solver.set_model()
        solver.exec()
        del solver
# Out:
# 0

# %%
main()
# Out:
# Using train mode
#
# [INFO] Exp. name : cv11Lu_asr_lstm4atthead_allvocab-CDR-5fold-3_sd0
# [INFO] Loading data... large dataset may took a while.
# Load data for training/validation, store tokenizer and input/output shape
# Prepare dataloader for training/validation
# Interface for creating all kinds of dataset
# import VAGDataset as Dataset
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-3-2']
# Mozillacv11Dataset CTT5-3-2 found wav data: 17
# text len: 17
# remove None, then wav data: 17, text len: 17
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-1-2', 'CTT5-2-2', 'CTT5-5-2', 'CTT5-4-2']
# Mozillacv11Dataset CTT5-1-2 found wav data: 19
# Mozillacv11Dataset CTT5-2-2 found wav data: 18
# Mozillacv11Dataset CTT5-5-2 found wav data: 17
# Mozillacv11Dataset CTT5-4-2 found wav data: 17
# text len: 71
# remove None, then wav data: 71, text len: 71
# [INFO] Data spec. | Corpus = vagcdr (from /home/jupyter-jason5/data_process)
# [INFO]            | Train sets = ['CTT5-1-2', 'CTT5-2-2', 'CTT5-5-2', 'CTT5-4-2']	| Number of utts = 71
# [INFO]            | Dev sets = ['CTT5-3-2']	| Number of utts = 17
# [INFO]            | Batch size = 1		| Bucketing = True
# [INFO] I/O spec.  | Audio feature = fbank	| feature dim = 120
# Setup ASR model and optimizer
# [INFO] Model spec.| Encoder's downsampling rate of time axis is 4.
# [INFO]            | VCC Extractor w/ time downsampling rate = 4 in encoder enabled.
# # Losses
# # Note: zero_infinity=False is unstable?
# # Optimizer
# [INFO] Optim.spec.| Algo. = Adadelta	| Lr = 1.0	 (Scheduler = fixed)| Scheduled sampling = False
# # Enable AMP if needed
# [INFO] Load ckpt from ./ckpt/cv11Lu_asr_lstm4atthead_allvocab_sd0/best_att-VAG01.pth, restarting at step 795000 )
# encoder.layers.0.extractor.0.weight
# encoder.layers.0.extractor.0.bias
# encoder.layers.4.layer.weight_ih_l0_reverse
# encoder.layers.4.layer.weight_hh_l0_reverse
# encoder.layers.4.layer.bias_ih_l0_reverse
# encoder.layers.4.layer.bias_hh_l0_reverse
# fc.weight
# fc.bias
# Training End-to-end ASR system
# [INFO] Total training steps 1.0K.
# self.tr_set: 71
# /home/jupyter-jason5/LAS_Mandarin_PyTorch-master/core/module.py:51: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   feat_len = feat_len // 4
# tensor(9.3790, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(8.7566, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(8.5739, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.8648, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.7662, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.8543, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.4739, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.9055, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.2290, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(7.0024, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.6871, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.4362, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(6.2233, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.9875, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.7130, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.3679, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.2768, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(5.3574, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.7469, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.7503, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.5889, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.5699, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.3873, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.5225, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.8723, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(4.0536, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.7951, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.8677, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.7493, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.5168, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.2627, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.2809, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.3330, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.3340, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.0427, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(3.0077, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.7912, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.6794, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.5181, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.7195, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.2029, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.5392, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.1665, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.0708, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.0807, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(2.0914, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.9873, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.7979, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.9036, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.7626, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.6877, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.5027, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.5432, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.5547, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.5470, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.3725, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.1406, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.2574, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.0963, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.1275, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(1.0587, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.8941, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.7881, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.7973, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.7417, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.8096, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.7433, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6402, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.5804, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.5336, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6447, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.5882, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.6020, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4945, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4934, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4572, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.4379, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3948, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3329, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3283, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2880, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2491, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.3054, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2248, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1811, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.2077, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1991, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1718, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1672, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1928, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1951, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1264, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1270, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1674, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1284, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1322, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0913, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1409, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1155, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1219, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0965, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1080, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1071, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1004, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1013, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0841, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1009, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0828, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0767, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.1112, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0749, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0969, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0829, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0670, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0738, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0718, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0644, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0758, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0653, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0875, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0411, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0535, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0763, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0741, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0597, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0568, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0678, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0600, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0540, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0754, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0457, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0723, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0649, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0389, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0608, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0685, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0234, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0463, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0642, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0309, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0538, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0451, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0476, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0516, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0495, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0381, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0401, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0388, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0641, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0283, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0649, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0396, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0482, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0484, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0304, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0377, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0558, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0454, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0459, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0388, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0393, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0531, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0271, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0385, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0385, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0456, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0288, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0504, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0830, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0558, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0335, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0422, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0482, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0447, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0314, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0292, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0312, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0317, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0352, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0302, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0511, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0286, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0474, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0352, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0377, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0559, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0305, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0333, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0442, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0472, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0260, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0357, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# tensor(0.0538, device='cuda:0', grad_fn=<AddBackward0>)
#
# self.tr_set: 71
# 14001
# [INFO] Exp. name : cv11Lu_asr_lstm4atthead_allvocab-CDR-5fold-4_sd0
# [INFO] Loading data... large dataset may took a while.
# Load data for training/validation, store tokenizer and input/output shape
# Prepare dataloader for training/validation
# Interface for creating all kinds of dataset
# import VAGDataset as Dataset
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-4-2']
# Mozillacv11Dataset CTT5-4-2 found wav data: 17
# text len: 17
# remove None, then wav data: 17, text len: 17
# [VAGDataset] path: /home/jupyter-jason5/data_process, split: ['CTT5-1-2', 'CTT5-2-2', 'CTT5-3-2', 'CTT5-5-2']
# Mozillacv11Dataset CTT5-1-2 found wav data: 19
# Mozillacv11Dataset CTT5-2-2 found wav data: 18
# Mozillacv11Dataset CTT5-3-2 found wav data: 17
# Mozillacv11Dataset CTT5-5-2 found wav data: 17
# text len: 71
# remove None, then wav data: 71, text len: 71
# [INFO] Data spec. | Corpus = vagcdr (from /home/jupyter-jason5/data_process)
# [INFO]            | Train sets = ['CTT5-1-2', 'CTT5-2-2', 'CTT5-3-2', 'CTT5-5-2']	| Number of utts = 71
# [INFO]            | Dev sets = ['CTT5-4-2']	| Number of utts = 17
# [INFO]            | Batch size = 1		| Bucketing = True
# [INFO] I/O spec.  | Audio feature = fbank	| feature dim = 120
# Setup ASR model and optimizer
# [INFO] Model spec.| Encoder's downsampling rate of time axis is 4.
# [INFO]            | VCC Extractor w/ time downsampling rate = 4 in encoder enabled.
# # Losses
# # Note: zero_infinity=False is unstable?
# # Optimizer
# [INFO] Optim.spec.| Algo. = Adadelta	| Lr = 1.0	 (Scheduler = fixed)| Scheduled sampling = False
# # Enable AMP if needed
# [INFO] Load ckpt from ./ckpt/cv11Lu_asr_lstm4atthead_allvocab_sd0/best_att-VAG01.pth, restarting at step 795000 )
# encoder.layers.0.extractor.0.weight
# encoder.layers.0.extractor.0.bias
# encoder.layers.4.layer.weight_ih_l0_reverse
# encoder.layers.4.layer.weight_hh_l0_reverse
# encoder.layers.4.layer.bias_ih_l0_reverse
# encoder.layers.4.layer.bias_hh_l0_reverse
# fc.weight
# fc.bias
# Training End-to-end ASR system
# [INFO] Total training steps 1.0K.
# self.tr_set: 71

# %%
print('asd')

# %%
# !python eval.py --file ~/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv
# Out:
# ============  Result of /home/jupyter-jason3/LAS_Mandarin_PyTorch-master/result/mozillacv11_asr_stm4atthead-test_test_output.csv ============
#  -----------------------------------------------------------------------
# | Statics		|  Truth	|  Prediction	| Abs. Diff.	|
#  -----------------------------------------------------------------------
# | Avg. # of chars	|  8.01	|  8.10	|  0.16		|
# | Avg. # of words	|  1.00	|  1.00	|  0.00		|
#  -----------------------------------------------------------------------
#  ---------------------------------------------------------------
# | Error Rate (%)| Mean		| Std.		| Min./Max.	|
#  ---------------------------------------------------------------
# | Character	| 7.9479	| 21.68		| 0.00/240.00	|
# | Word		| 18.1725	| 38.56		| 0.00/100.00	|
#  ---------------------------------------------------------------
# Note : If the text unit is phoneme, WER = PER and CER is meaningless.
